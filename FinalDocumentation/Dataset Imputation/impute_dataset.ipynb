# %%
import numpy as np
import cv2
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('FeatureCSV/traffic_sign_concat.csv', header=None)

# %%
df.head(10)
# Out:
#         0         1        2        3         4        5         6    \
# 0  0.717706  3.201510  5.65465  6.46858 -12.63080 -8.19701  12.74570
# 1  0.695797  3.119080  5.29159  6.10701 -11.85070  8.34103 -12.17270
# 2  0.700625  3.103870  5.30741  6.24999 -12.27140  8.28229 -12.11470
# 3  0.703968  3.126730  5.36697  6.19499 -12.93280 -7.76169  11.97860
# 4  0.691544  3.176780  5.04041  6.92714 -13.19840 -8.69322  12.97810
# 5  0.659927  3.100250  5.48183  5.52646 -11.66390 -7.07696  11.04270
# 6  0.602163  3.338880  3.91068  3.99360  -8.06046  5.87900  -8.13914
# 7  0.620738  3.142990  3.92975  4.37191  -8.67028  6.02523  -8.67626
# 8  0.332547  0.788813  2.12563  2.33050   4.56046  2.75639  -5.58830
# 9  0.661319  3.335680  5.24118  5.51835  11.40370  7.29140 -10.92040
#
#         7         8         9    ...       439       440       441       442  \
# 0  0.500796  0.500796  0.500796  ...  0.339542  0.548712  0.548712  0.447122
# 1  0.491922  0.491922  0.491922  ...  0.516569  0.516569  0.516569  0.370025
# 2  0.515312  0.515312  0.515312  ...  0.549930  0.549930  0.549930  0.238128
# 3  0.506153  0.506153  0.506153  ...  0.446814  0.509295  0.509295  0.478593
# 4  0.514244  0.514244  0.514244  ...  0.268622  0.570055  0.570055  0.413673
# 5  0.414042  0.414042  0.414042  ...  0.348871  0.609085  0.609085  0.246246
# 6  0.455838  0.455838  0.455838  ...  0.514473  0.514473  0.514473  0.316625
# 7  0.465414  0.465414  0.465414  ...  0.398943  0.589304  0.589304  0.271832
# 8  0.342688  0.450477  0.450477  ...  0.232105  0.505967  0.505967  0.505967
# 9  0.496286  0.496286  0.496286  ...  0.306597  0.603923  0.603923  0.336381
#
#         443       444       445       446       447  448
# 0  0.203915  0.067373  0.145494  0.038104  0.091668    1
# 1  0.165232  0.030591  0.085255  0.030667  0.144727    1
# 2  0.084238  0.013637  0.058353  0.050888  0.131366    1
# 3  0.147878  0.063688  0.119419  0.035364  0.077598    1
# 4  0.240577  0.049767  0.173476  0.056357  0.086459    1
# 5  0.119228  0.040305  0.189101  0.055787  0.122023    1
# 6  0.153156  0.032676  0.169646  0.072283  0.205018    1
# 7  0.141014  0.033306  0.151324  0.086654  0.122909    1
# 8  0.336020  0.031355  0.199702  0.084407  0.110318    1
# 9  0.125914  0.030831  0.029046  0.097945  0.173571    1
#
# [10 rows x 449 columns]

# %%
df_clean = df.replace([np.inf, -np.inf, 0], np.nan)

df_clean.isnull().sum()
# Out:
# 0      328
# 1      352
# 2      378
# 3      378
# 4      378
#       ...
# 444    172
# 445    166
# 446    160
# 447    152
# 448      0
# Length: 449, dtype: int64

# %%
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(strategy='median')
imputer.fit(df_clean)
df_imputed = imputer.transform(df_clean)

# %%
df_imputed = pd.DataFrame(df_imputed)
df_imputed.isnull().sum()
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 444    0
# 445    0
# 446    0
# 447    0
# 448    0
# Length: 449, dtype: int64

# %%
df_imputed.to_csv('FeatureCSV/traffic_sign_concat_imputed.csv', header=False, index=False)
